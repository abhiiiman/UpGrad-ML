# %% [markdown]
# # Data Cleaning Assignment - 2
# ## Dataset - *Meteorite Landings*
# ## Submitted By - *Abhijit Mandal*
# ### Enrollment ID - *210BTCSEAM024*
# ### Semester - *5*
# ### Course - *B.Tech. CSE AI/ML*

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Supressing the warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the Data

# %%
df = pd.read_csv("meteorite-landings.csv")

# %%
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
df.shape
# Out:
# (45716, 10)

# %% [markdown]
# ## Checking for the nulls

# %%
df.isnull().sum()
# Out:
# name              0
# id                0
# nametype          0
# recclass          0
# mass            131
# fall              0
# year            288
# reclat         7315
# reclong        7315
# GeoLocation    7315
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 22364

# %% [markdown]
# ## Plotting the heatmap for the nulls

# %%
plt.figure(figsize = (16,9))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name           0
# id             0
# nametype       0
# recclass       0
# mass           0
# fall           0
# year           0
# reclat         0
# reclong        0
# GeoLocation    0
# dtype: int64

# %%
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
plt.figure(figsize = (16,9))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (38116, 10)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Correcting the range of year in the df

# %%
df = df[(df['year'] >= 1500) & (df['year'] <= 2023)]

# %%
df.tail()
# Out:
#              name     id nametype              recclass    mass   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite   172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46.0  Found
# 45713        Zlin  30410    Valid                    H4     3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200.0  Found
#
#          year    reclat    reclong               GeoLocation
# 45711  1990.0  29.03700   17.01850    (29.037000, 17.018500)
# 45712  1999.0  13.78333    8.96667     (13.783330, 8.966670)
# 45713  1939.0  49.25000   17.66667    (49.250000, 17.666670)
# 45714  2003.0  49.78917   41.50460    (49.789170, 41.504600)
# 45715  1976.0  33.98333 -115.68333  (33.983330, -115.683330)

# %% [markdown]
# ## Checking for the datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38110 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         38110 non-null  object
#  1   id           38110 non-null  int64
#  2   nametype     38110 non-null  object
#  3   recclass     38110 non-null  object
#  4   mass         38110 non-null  float64
#  5   fall         38110 non-null  object
#  6   year         38110 non-null  float64
#  7   reclat       38110 non-null  float64
#  8   reclong      38110 non-null  float64
#  9   GeoLocation  38110 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.2+ MB

# %%
df['year'] = df['year'].astype("int")

# %%
df['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 38110 entries, 0 to 45715
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 38110 non-null  int32
# dtypes: int32(1)
# memory usage: 446.6 KB

# %%
df['year']
# Out:
# 0        1880
# 1        1951
# 2        1952
# 3        1976
# 4        1902
#          ...
# 45711    1990
# 45712    1999
# 45713    1939
# 45714    2003
# 45715    1976
# Name: year, Length: 38110, dtype: int32

# %% [markdown]
# ## Latitude ranges from -90 to 90 and Longitude ranges from -180 to 180

# %%
df = df[(df['reclat'] >= -90) & (df['reclat'] <= 90) & (df['reclong'] >= -180) & (df['reclong'] <= 180)]
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...

# %%
df['reclat'] = df['reclat'].astype("float64")

# %%
df['reclat'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 38110 entries, 0 to 45715
# Series name: reclat
# Non-Null Count  Dtype
# --------------  -----
# 38110 non-null  float64
# dtypes: float64(1)
# memory usage: 595.5 KB

# %%
df['reclat'].unique()
# Out:
# array([50.775  , 56.18333, 54.21667, ..., 31.2    , 29.037  , 49.78917])

# %%
df[df['reclat'] != ...]
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...

# %%
df['reclong'].unique()
# Out:
# array([   6.08333,   10.23333, -113.     , ...,    8.96667,   41.5046 ,
#        -115.68333])

# %%
df[df['reclong'] != ...]
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...

# %% [markdown]
# ## Converting the categorical features

# %%
df['fall'] = df['fall'].astype('category')
df['fall'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 38110 entries, 0 to 45715
# Series name: fall
# Non-Null Count  Dtype
# --------------  -----
# 38110 non-null  category
# dtypes: category(1)
# memory usage: 335.1 KB

# %%
df['nametype'] = df['nametype'].astype('category')

# %%
df['nametype'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 38110 entries, 0 to 45715
# Series name: nametype
# Non-Null Count  Dtype
# --------------  -----
# 38110 non-null  category
# dtypes: category(1)
# memory usage: 335.1 KB

# %% [markdown]
# ## Strip leading and trailing spaces from object columns

# %%
df['name'] = df['name'].str.strip()
df['GeoLocation'] = df['GeoLocation'].str.strip()

# %%
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...

# %% [markdown]
# ## Detecting and Removing the Outliers

# %%
Q1 = df['mass'].quantile(0.25)
Q3 = df['mass'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['mass'] >= Q1 - 1.5 * IQR) & (df['mass'] <= Q3 + 1.5 * IQR)]

# %%
df
# Out:
#                   name     id nametype              recclass   mass   fall  \
# 0               Aachen      1    Valid                    L5   21.0   Fell
# 17             Al Rais    446    Valid                CR2-an  160.0   Fell
# 22     Alby sur Chéran    458    Valid         Eucrite-mmict  252.0   Fell
# 42              Aomori   2313    Valid                    L6  320.0   Fell
# 48                Asco   2345    Valid                    H6   41.0   Fell
# ...                ...    ...      ...                   ...    ...    ...
# 45704            Zerga  30402    Valid                   LL6   76.0  Found
# 45711       Zillah 002  31356    Valid               Eucrite  172.0  Found
# 45712           Zinder  30409    Valid  Pallasite, ungrouped   46.0  Found
# 45713             Zlin  30410    Valid                    H4    3.3  Found
# 45715       Zulu Queen  30414    Valid                  L3.7  200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32031 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         32031 non-null  object
#  1   id           32031 non-null  int64
#  2   nametype     32031 non-null  category
#  3   recclass     32031 non-null  object
#  4   mass         32031 non-null  float64
#  5   fall         32031 non-null  category
#  6   year         32031 non-null  int32
#  7   reclat       32031 non-null  float64
#  8   reclong      32031 non-null  float64
#  9   GeoLocation  32031 non-null  object
# dtypes: category(2), float64(3), int32(1), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df['nametype'].unique()
# Out:
# ['Valid', 'Relict']
# Categories (2, object): ['Relict', 'Valid']

# %% [markdown]
# ## Cleaned Data

# %%
df
# Out:
#                   name     id nametype              recclass   mass   fall  \
# 0               Aachen      1    Valid                    L5   21.0   Fell
# 17             Al Rais    446    Valid                CR2-an  160.0   Fell
# 22     Alby sur Chéran    458    Valid         Eucrite-mmict  252.0   Fell
# 42              Aomori   2313    Valid                    L6  320.0   Fell
# 48                Asco   2345    Valid                    H6   41.0   Fell
# ...                ...    ...      ...                   ...    ...    ...
# 45704            Zerga  30402    Valid                   LL6   76.0  Found
# 45711       Zillah 002  31356    Valid               Eucrite  172.0  Found
# 45712           Zinder  30409    Valid  Pallasite, ungrouped   46.0  Found
# 45713             Zlin  30410    Valid                    H4    3.3  Found
# 45715       Zulu Queen  30414    Valid                  L3.7  200.0  Found
#
#        year    reclat    reclong               GeoLocation
# ...
